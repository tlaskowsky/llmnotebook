# %% [markdown]
# #
# # =================================================================================
# #  ようこそ！Jupyter Notebook 練習ノートブックへ
# # =================================================================================
# #
# #  このノートブックは、Jupyter Notebookの基本的な使い方を学ぶためのものです。
# #  指示に従って、各「セル」を一つずつ実行してみてください。
# #
# #  ---------------------------------------------------------------------------------
# #

# %% [markdown]
# #  ✅ 1. セルとは？
# #
# #  このノートブックは、「セル」と呼ばれるブロックで構成されています。
# #  セルには2つの主要な種類があります：
# #
# #  1.  **Markdownセル**: このセル（今あなたが見ているセル）のように、テキストや説明を書くためのものです。
# #  2.  **コードセル**: Pythonなどのプログラミングコードを書き、実行するためのものです。
# #
# #  ---------------------------------------------------------------------------------
# #

# %% [markdown]
# #  ✅ 2. セルの実行方法
# #
# #  セルを実行するには、セルを選択して（クリックして）、キーボードで `Shift + Enter` を押します。
# #  下のコードセルを選択して、`Shift + Enter` を押してみてください。
# #  "Hello, Jupyter!" というメッセージが表示されるはずです。
# #
# # ---------------------------------------------------------------------------------

# %%
print("Hello, Jupyter!")

# %% [markdown]
# # =================================================================================
# #  ✅ 3. コードセルで計算してみよう
# # =================================================================================
# #
# #  コードセルでは、Pythonコードを使って計算ができます。
# #  下のセルを実行して、`1 + 1` の計算結果を確認してみましょう。
# #
# # ---------------------------------------------------------------------------------

# %%
1 + 1

# %% [markdown]
# # =================================================================================
# #  ✅ 4. 変数を使ってみよう
# # =================================================================================
# #
# #  Jupyter Notebookの便利な点は、一度実行したセルの結果（変数など）を
# #  他のセルで使えることです。
# #
# #  まず、下のセルを実行して、`my_name` という変数にあなたの名前を保存してください。
# #  （"あなたの名前" の部分を書き換えてください）
# #
# # ---------------------------------------------------------------------------------

# %%
my_name = "あなたの名前"

# %% [markdown]
# # =================================================================================
# #
# #  次に、下のセルを実行してください。
# #  前のセルで定義した `my_name` 変数を使って、挨拶メッセージが表示されます。
# #
# # ---------------------------------------------------------------------------------

# %%
print(f"こんにちは、{my_name}さん！")

# %%
# =================================================================================
#  ✅ 5. Markdownセルで文章を書いてみよう
# =================================================================================
#
#  このセルは現在「コードセル」になっていますが、「Markdownセル」に変更することができます。
#
#  手順：
#  1. このセルを選択します。
#  2. 上部のメニューバーにあるドロップダウンメニュー（通常 "Code" と表示されています）を
#     クリックし、"Markdown" を選択します。
#  3. セルの内容を好きな文章に書き換えてみましょう。
#  4. `Shift + Enter` を押して、書いた文章がきれいに表示されることを確認してください。
#
#  例：
#  # これは見出しです
#  * これはリストの項目です
#  * **太字**も使えます
#

# %%
# =================================================================================
#  ✅ 6. セルの追加と削除
# =================================================================================
#
#  新しいセルを追加したり、不要なセルを削除したりすることも簡単です。
#
#  **セルの追加:**
#  - このセルの下（または上）に新しいセルを追加するには、上部メニューの `+` ボタンをクリックするか、
#    `Edit` > `Insert Cell Above` / `Insert Cell Below` を選択します。
#
#  **セルの削除:**
#  - セルを削除するには、そのセルを選択し、ハサミのアイコン（Cut）をクリックするか、
#    `Edit` > `Delete Cells` を選択します。
#
# ---------------------------------------------------------------------------------
#

# %%
#  練習は以上です！
#  これで、あなたはJupyter Notebookの基本的な操作をマスターしました。
#  メインのワークショップに進む準備は万端です！
#
# =================================================================================
